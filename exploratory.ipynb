# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.1     ✔ purrr   1.0.1
# ✔ tibble  3.1.8     ✔ dplyr   1.1.0
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.3     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
df = pd.read_csv('CCRB-Complaint-Data/allegations_202007271729.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    unique_mos_id first_name last_name command_now  shield_no  complaint_id
# 0          10004   Jonathan      Ruiz     078 PCT       8409         42835  \
# 1          10007       John     Sears     078 PCT       5952         24601
# 2          10007       John     Sears     078 PCT       5952         24601
# 3          10007       John     Sears     078 PCT       5952         26146
# 4          10009      Noemi    Sierra     078 PCT      24058         40253
#
#    month_received  year_received  month_closed  year_closed
# 0               7           2019             5         2020  \
# 1              11           2011             8         2012
# 2              11           2011             8         2012
# 3               7           2012             9         2013
# 4               8           2018             2         2019
#
#   command_at_incident rank_abbrev_incident rank_abbrev_now        rank_now
# ...

# %%
df['unsubstantiated_or_exonerated'] = df['board_disposition'].isin(['Unsubstantiated', 'Exonerated']).astype(int)
df.head()
# Out:
#    unique_mos_id first_name last_name command_now  shield_no  complaint_id
# 0          10004   Jonathan      Ruiz     078 PCT       8409         42835  \
# 1          10007       John     Sears     078 PCT       5952         24601
# 2          10007       John     Sears     078 PCT       5952         24601
# 3          10007       John     Sears     078 PCT       5952         26146
# 4          10009      Noemi    Sierra     078 PCT      24058         40253
#
#    month_received  year_received  month_closed  year_closed
# 0               7           2019             5         2020  \
# 1              11           2011             8         2012
# 2              11           2011             8         2012
# 3               7           2012             9         2013
# 4               8           2018             2         2019
#
#   command_at_incident rank_abbrev_incident rank_abbrev_now        rank_now
# ...

# %%
# %%R -i df

df.mos_ethnicity.unique()
df['white'] = (df.mos_ethnicity == 'White').astype(int)
# crosstabs <- xtabs(~unsubstantiated_or_exonerated + mos_gender + mos_age_incident, data = df)
# crosstabs

# %%
# %%R -i df
#
# model <- glm(unsubstantiated_or_exonerated ~ white , family=binomial(link='logit'), data=df)
# summary(model)
# Out:
# Call:
# glm(formula = unsubstantiated_or_exonerated ~ white, family = binomial(link = "logit"),
#     data = df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.6851   0.7440   0.7440   0.7711   0.7711
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  1.06059    0.01851  57.311  < 2e-16 ***
# white        0.08234    0.02538   3.244  0.00118 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 37432  on 33357  degrees of freedom
# Residual deviance: 37421  on 33356  degrees of freedom
# AIC: 37425
#
# Number of Fisher Scoring iterations: 4

# %%
# %%R
#
# exp(coef(model))
# Out:
# (Intercept)       white
#    2.888069    1.085821
